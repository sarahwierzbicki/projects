# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahwierzbicki/projects/blob/main/NYC_Taxi_Trip_Duration_Prediction_using_a_DNN_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !pip install fastparquet
import fastparquet
import pandas as pd
import numpy as np
import datetime
# Out:
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.11/dist-packages (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2.0.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2.9.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2025.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastparquet) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)

# %%
jan_tax = pd.read_parquet('yellow_tripdata_2020-01 (1).parquet', engine='fastparquet')
jan_weather = pd.read_csv('/content/export (1).csv')
location_zones = pd.read_csv('/content/taxi_zone_lookup.csv')

# %%
location_zones.columns
# Out:
# Index(['LocationID', 'Borough', 'Zone', 'service_zone'], dtype='object')

# %%
jan_tax.head(5)
jan_tax['PULocationID']
# Out:
# 0          238
# 1          239
# 2          238
# 3          238
# 4          193
#           ...
# 6405003    191
# 6405004    186
# 6405005    164
# 6405006     10
# 6405007    247
# Name: PULocationID, Length: 6405008, dtype: int64

# %%
location_zones
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %%
#merge taxi zone with jan to find zones of each pick up
location = location_zones.rename(columns={'LocationID': 'PULocationID'})
pickup = pd.merge(jan_tax, location, on='PULocationID', how='inner')
pickup.info()
pickup.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6405008 entries, 0 to 6405007
# Data columns (total 22 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
#  19  Borough                object
#  20  Zone                   object
#  21  service_zone           object
# dtypes: datetime64[ns](2), float64(12), int64(4), object(4)
# memory usage: 1.0+ GB
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1         1  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2         1  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3         1  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4         2  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N           238           239
# 1            1.2         1.0                  N           239           238
# 2            0.6         1.0                  N           238           238
# 3            0.8         1.0                  N           238           151
# 4            0.0         1.0                  N           193           193
#
#    payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# 0             1  ...      0.5        1.47           0.0
# 1             1  ...      0.5        1.50           0.0
# 2             1  ...      0.5        1.00           0.0
# 3             1  ...      0.5        1.36           0.0
# 4             2  ...      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee  \
# 0                    0.3         11.27                   2.5          NaN
# 1                    0.3         12.30                   2.5          NaN
# 2                    0.3         10.80                   2.5          NaN
# 3                    0.3          8.16                   0.0          NaN
# 4                    0.3          4.80                   0.0          NaN
#
#      Borough                     Zone service_zone
# 0  Manhattan    Upper West Side North  Yellow Zone
# 1  Manhattan    Upper West Side South  Yellow Zone
# 2  Manhattan    Upper West Side North  Yellow Zone
# 3  Manhattan    Upper West Side North  Yellow Zone
# 4     Queens  Queensbridge/Ravenswood    Boro Zone
#
# [5 rows x 22 columns]

# %%
jan_trips = pickup.loc[pickup['DOLocationID'].isin([1, 132, 138])]
jan_trips[~jan_trips['PULocationID'].isin([1, 132, 138])]
jan_trips
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 594             2  2020-01-01 00:42:43   2020-01-01 01:06:32              1.0
# 6047            2  2020-01-01 00:35:43   2020-01-01 01:14:31              1.0
# 11967           2  2020-01-01 00:17:49   2020-01-01 00:56:41              2.0
# 12225           2  2020-01-01 00:34:05   2020-01-01 00:51:26              1.0
# 12382           1  2020-01-01 00:39:15   2020-01-01 00:39:50              1.0
# ...           ...                  ...                   ...              ...
# 6402566         2  2020-01-30 16:11:00   2020-01-30 17:39:00              NaN
# 6403262         2  2020-01-31 05:57:09   2020-01-31 06:10:51              NaN
# 6404051         2  2020-01-31 13:00:47   2020-01-31 13:57:22              NaN
# 6404186         2  2020-01-31 14:02:00   2020-01-31 14:16:00              NaN
# 6404946         2  2020-01-31 22:19:53   2020-01-31 22:21:33              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 594               7.09         1.0                  N           161
# 6047             18.34         2.0                  N           249
# 11967            10.74         1.0                  N           100
# 12225             9.00         1.0                  N           161
# 12382             0.00         1.0                  N           132
# ...                ...         ...                ...           ...
# 6402566          20.32         NaN               None           232
# 6403262           7.60         NaN               None           216
# 6404051          34.11         NaN               None           140
# 6404186           8.27         NaN               None             9
# 6404946           1.28         NaN               None           132
#
#          DOLocationID  payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# 594               138             2  ...      0.5        0.00          0.00
# 6047              132             1  ...      0.5       12.28          6.12
# 11967             138             1  ...      0.5       14.38          6.12
# 12225             138             1  ...      0.5        7.18          6.12
# 12382             132             4  ...      0.5        0.00          0.00
# ...               ...           ...  ...      ...         ...           ...
# 6402566           132             0  ...      0.5        0.00          0.00
# 6403262           138             0  ...      0.0        0.00          0.00
# 6404051           132             0  ...      0.0        0.00          6.12
# 6404186           138             0  ...      0.5        0.00          0.00
# 6404946           132             0  ...      0.0        0.00          0.00
#
#          improvement_surcharge  total_amount  congestion_surcharge  \
# 594                        0.3         27.80                   2.5
# 6047                       0.3         73.70                   2.5
# 11967                      0.3         62.30                   2.5
# 12225                      0.3         43.10                   2.5
# 12382                      0.3          3.80                   0.0
# ...                        ...           ...                   ...
# 6402566                    0.3         58.79                   NaN
# 6403262                    0.3         43.00                   NaN
# 6404051                    0.3         48.58                   NaN
# 6404186                    0.3         28.41                   NaN
# 6404946                    0.3         36.00                   NaN
#
#          airport_fee    Borough                     Zone service_zone
# 594              NaN  Manhattan           Midtown Center  Yellow Zone
# 6047             NaN  Manhattan             West Village  Yellow Zone
# 11967            NaN  Manhattan         Garment District  Yellow Zone
# 12225            NaN  Manhattan           Midtown Center  Yellow Zone
# 12382            NaN     Queens              JFK Airport     Airports
# ...              ...        ...                      ...          ...
# 6402566          NaN  Manhattan  Two Bridges/Seward Park  Yellow Zone
# 6403262          NaN     Queens         South Ozone Park    Boro Zone
# 6404051          NaN  Manhattan          Lenox Hill East  Yellow Zone
# 6404186          NaN     Queens               Auburndale    Boro Zone
# 6404946          NaN     Queens              JFK Airport     Airports
#
# [128147 rows x 22 columns]

# %%
#rename drop off to airport
def airport(x):
  if x == 1:
      return 'Newark'
  elif x == 132:
      return 'JFK'
  elif x == 138:
      return 'LaGuardia'

# %%
jan_trips['airport']=jan_trips['DOLocationID'].apply(airport)
# Out:
# <ipython-input-178-d58d2a0e0153>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['airport']=jan_trips['DOLocationID'].apply(airport)

# %%
# drop NaN from RateCodeID and those not between 1 and 6
jan_trips.dropna(subset=['RatecodeID'])

#drop NaN from passenger count
jan_trips.dropna(subset=['passenger_count'])
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 594             2  2020-01-01 00:42:43   2020-01-01 01:06:32              1.0
# 6047            2  2020-01-01 00:35:43   2020-01-01 01:14:31              1.0
# 11967           2  2020-01-01 00:17:49   2020-01-01 00:56:41              2.0
# 12225           2  2020-01-01 00:34:05   2020-01-01 00:51:26              1.0
# 12382           1  2020-01-01 00:39:15   2020-01-01 00:39:50              1.0
# ...           ...                  ...                   ...              ...
# 6338772         1  2020-01-31 23:00:14   2020-01-31 23:00:22              1.0
# 6338928         1  2020-01-31 23:12:30   2020-01-31 23:20:40              1.0
# 6339436         1  2020-01-31 23:51:05   2020-01-31 23:51:08              1.0
# 6339465         2  2020-01-31 23:54:51   2020-01-31 23:56:50              1.0
# 6339508         1  2020-01-31 23:14:54   2020-01-31 23:15:57              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 594               7.09         1.0                  N           161
# 6047             18.34         2.0                  N           249
# 11967            10.74         1.0                  N           100
# 12225             9.00         1.0                  N           161
# 12382             0.00         1.0                  N           132
# ...                ...         ...                ...           ...
# 6338772           0.00         1.0                  N           132
# 6338928           1.30         1.0                  N           138
# 6339436           0.00         1.0                  N           132
# 6339465           0.05         2.0                  N           132
# 6339508           0.00         1.0                  N           132
#
#          DOLocationID  payment_type  ...  tip_amount  tolls_amount  \
# 594               138             2  ...        0.00          0.00
# 6047              132             1  ...       12.28          6.12
# 11967             138             1  ...       14.38          6.12
# 12225             138             1  ...        7.18          6.12
# 12382             132             4  ...        0.00          0.00
# ...               ...           ...  ...         ...           ...
# 6338772           132             4  ...        0.00          0.00
# 6338928           138             2  ...        0.00          0.00
# 6339436           132             3  ...        0.00          0.00
# 6339465           132             2  ...        0.00          0.00
# 6339508           132             3  ...        0.00          0.00
#
#          improvement_surcharge  total_amount  congestion_surcharge  \
# 594                        0.3          27.8                   2.5
# 6047                       0.3          73.7                   2.5
# 11967                      0.3          62.3                   2.5
# 12225                      0.3          43.1                   2.5
# 12382                      0.3           3.8                   0.0
# ...                        ...           ...                   ...
# 6338772                    0.3           3.8                   0.0
# 6338928                    0.3           9.3                   0.0
# 6339436                    0.3           3.8                   0.0
# 6339465                    0.3          52.8                   0.0
# 6339508                    0.3           3.8                   0.0
#
#          airport_fee    Borough               Zone  service_zone    airport
# 594              NaN  Manhattan     Midtown Center   Yellow Zone  LaGuardia
# 6047             NaN  Manhattan       West Village   Yellow Zone        JFK
# 11967            NaN  Manhattan   Garment District   Yellow Zone  LaGuardia
# 12225            NaN  Manhattan     Midtown Center   Yellow Zone  LaGuardia
# 12382            NaN     Queens        JFK Airport      Airports        JFK
# ...              ...        ...                ...           ...        ...
# 6338772          NaN     Queens        JFK Airport      Airports        JFK
# 6338928          NaN     Queens  LaGuardia Airport      Airports  LaGuardia
# 6339436          NaN     Queens        JFK Airport      Airports        JFK
# 6339465          NaN     Queens        JFK Airport      Airports        JFK
# 6339508          NaN     Queens        JFK Airport      Airports        JFK
#
# [128018 rows x 23 columns]

# %%
#remove unneeded columns
jan_trips.drop('VendorID', axis = 1, inplace=True)
jan_trips.drop('store_and_fwd_flag', axis = 1, inplace=True)
jan_trips.drop('airport_fee', axis = 1, inplace=True)
jan_trips.drop('congestion_surcharge', axis = 1, inplace=True)
jan_trips.drop('payment_type', axis = 1, inplace=True)
jan_trips.drop('extra', axis = 1, inplace=True)
jan_trips.drop('service_zone', axis = 1, inplace=True)
# Out:
# <ipython-input-180-ab0e33609de2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips.drop('VendorID', axis = 1, inplace=True)
# <ipython-input-180-ab0e33609de2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips.drop('store_and_fwd_flag', axis = 1, inplace=True)
# <ipython-input-180-ab0e33609de2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips.drop('airport_fee', axis = 1, inplace=True)
# <ipython-input-180-ab0e33609de2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips.drop('congestion_surcharge', axis = 1, inplace=True)
# <ipython-input-180-ab0e33609de2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips.drop('payment_type', axis = 1, inplace=True)
# <ipython-input-180-ab0e33609de2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips.drop('extra', axis = 1, inplace=True)
# <ipython-input-180-ab0e33609de2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips.drop('service_zone', axis = 1, inplace=True)

# %%
#ride count by timeframe
#add column for 5 timeframe (morning (5-12), afternoon(12-4), evening(4-10), latenight(10-5))
def time_frame(x):
  if x in range(5,12):
      return 1
  elif x in range(12,16):
      return 2
  elif x in range(16,22):
      return 3
  else:
      return 4

# %%
jan_trips['pickup_day'] = jan_trips['tpep_pickup_datetime'].dt.day_name()
jan_trips['dropoff_day'] = jan_trips['tpep_dropoff_datetime'].dt.day_name()

jan_trips['pickup_hour']= jan_trips['tpep_pickup_datetime'].dt.hour
jan_trips['dropoff_hour']= jan_trips['tpep_dropoff_datetime'].dt.hour

jan_trips['date']=jan_trips['tpep_pickup_datetime'].dt.date
jan_trips['date'] = pd.to_datetime(jan_trips['date'])

day_int = {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6}
jan_trips['day_of_week'] = jan_trips['pickup_day'].map(day_int)
# Out:
# <ipython-input-182-63d98eac02ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['pickup_day'] = jan_trips['tpep_pickup_datetime'].dt.day_name()
# <ipython-input-182-63d98eac02ab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['dropoff_day'] = jan_trips['tpep_dropoff_datetime'].dt.day_name()
# <ipython-input-182-63d98eac02ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['pickup_hour']= jan_trips['tpep_pickup_datetime'].dt.hour
# <ipython-input-182-63d98eac02ab>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['dropoff_hour']= jan_trips['tpep_dropoff_datetime'].dt.hour
# <ipython-input-182-63d98eac02ab>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['date']=jan_trips['tpep_pickup_datetime'].dt.date
# <ipython-input-182-63d98eac02ab>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['date'] = pd.to_datetime(jan_trips['date'])
# <ipython-input-182-63d98eac02ab>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['day_of_week'] = jan_trips['pickup_day'].map(day_int)

# %%
jan_trips['pickup_timeframe']=jan_trips['pickup_hour'].apply(time_frame)
jan_trips['dropoff_timeframe']=jan_trips['dropoff_hour'].apply(time_frame)
# Out:
# <ipython-input-183-a2e1009a72eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['pickup_timeframe']=jan_trips['pickup_hour'].apply(time_frame)
# <ipython-input-183-a2e1009a72eb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['dropoff_timeframe']=jan_trips['dropoff_hour'].apply(time_frame)

# %%
from datetime import datetime
from datetime import timedelta
a = jan_trips['tpep_pickup_datetime']
b = jan_trips['tpep_dropoff_datetime']
c = b - a
c.describe()
# Out:
# count                       128147
# mean     0 days 00:35:20.650682419
# std      0 days 01:18:25.275711972
# min                0 days 00:00:00
# 25%                0 days 00:21:50
# 50%                0 days 00:29:39
# 75%                0 days 00:39:32
# max                0 days 23:59:56
# dtype: object

# %%
from datetime import datetime
from datetime import timedelta
a = jan_trips['tpep_pickup_datetime']
b = jan_trips['tpep_dropoff_datetime']
c = b - a
min = c.dt.total_seconds() / 60
jan_trips['ride_duration'] = min
jan_trips['ride_duration'] = jan_trips['ride_duration'].round(2)
# Out:
# <ipython-input-185-35e82beda34d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['ride_duration'] = min
# <ipython-input-185-35e82beda34d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_trips['ride_duration'] = jan_trips['ride_duration'].round(2)

# %%
# drop NaN from RateCodeID and those not between 1 and 6
jan_trips.dropna(subset=['RatecodeID'])

#drop NaN from passenger count
jan_trips.dropna(subset=['passenger_count'])


#find zones in manhattan
man_trips = jan_trips[jan_trips['Borough'] == 'Manhattan']

# %%
man_trips_filtered = man_trips[man_trips['Zone'].isin(man_trips['Zone'].value_counts()[man_trips['Zone'].value_counts() >= 1000].index)]

# %%
man_trips_filtered.head(5)
# Out:
#       tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 594    2020-01-01 00:42:43   2020-01-01 01:06:32              1.0
# 11967  2020-01-01 00:17:49   2020-01-01 00:56:41              2.0
# 12225  2020-01-01 00:34:05   2020-01-01 00:51:26              1.0
# 12399  2020-01-01 00:47:25   2020-01-01 01:34:58              1.0
# 13480  2020-01-01 01:29:13   2020-01-01 02:08:04              2.0
#
#        trip_distance  RatecodeID  PULocationID  DOLocationID  fare_amount  \
# 594             7.09         1.0           161           138         24.0
# 11967          10.74         1.0           100           138         38.0
# 12225           9.00         1.0           161           138         26.0
# 12399          17.65         2.0           162           132         52.0
# 13480          20.65         2.0           238           132         52.0
#
#        mta_tax  tip_amount  ...    airport  pickup_day  dropoff_day  \
# 594        0.5        0.00  ...  LaGuardia   Wednesday    Wednesday
# 11967      0.5       14.38  ...  LaGuardia   Wednesday    Wednesday
# 12225      0.5        7.18  ...  LaGuardia   Wednesday    Wednesday
# 12399      0.5       11.06  ...        JFK   Wednesday    Wednesday
# 13480      0.5       12.28  ...        JFK   Wednesday    Wednesday
#
#       pickup_hour dropoff_hour       date day_of_week pickup_timeframe  \
# 594             0            1 2020-01-01           2                4
# 11967           0            0 2020-01-01           2                4
# 12225           0            0 2020-01-01           2                4
# 12399           0            1 2020-01-01           2                4
# 13480           1            2 2020-01-01           2                4
#
#        dropoff_timeframe  ride_duration
# 594                    4          23.82
# 11967                  4          38.87
# 12225                  4          17.35
# 12399                  4          47.55
# 13480                  4          38.85
#
# [5 rows x 25 columns]

# %%
#deal with outliers
#minimum distance 1 mile
trips_dis = man_trips_filtered[(man_trips_filtered['trip_distance'] > 5) & (man_trips_filtered['trip_distance'] < 25)]
#minimum fare 10 dollars
trips_fare = trips_dis[(trips_dis['fare_amount'] > 10) & (trips_dis['fare_amount'] < 100)]
#minimum ride time of 10 minutes
trips_final = trips_fare[(trips_fare['ride_duration'] > 10) & (trips_dis['ride_duration'] < 100)]

#trips_final = trips_final[(trips_final['pickup_hour'] >= 10) & (trips_final['pickup_hour'] <= 20)]
# drop NaN from RateCodeID and those not between 1 and 6
trips_final = trips_final.dropna(subset=['RatecodeID'])

#drop NaN from passenger count
trips_final = trips_final.dropna(subset=['passenger_count'])
# Out:
# <ipython-input-189-8ad7db49574b>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   trips_final = trips_fare[(trips_fare['ride_duration'] > 10) & (trips_dis['ride_duration'] < 100)]

# %%
from scipy import stats

trips_final = trips_final[np.abs(stats.zscore(trips_final['trip_distance'])) < 3]
trips_final = trips_final[np.abs(stats.zscore(trips_final['ride_duration'])) < 3]

# %%
jan_weather.head(5)
# Out:
#                   date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  \
# 0  2020-01-01 00:00:00   3.6   1.7   5.0   NaN   NaN    NaN  17.3   NaN
# 1  2020-01-02 00:00:00   4.7   0.6   8.9   NaN   NaN    NaN  12.4   NaN
# 2  2020-01-03 00:00:00   7.6   6.7   8.3   NaN   NaN  257.0   8.4   NaN
# 3  2020-01-04 00:00:00   8.2   6.7   9.4   NaN   NaN    NaN   5.7   NaN
# 4  2020-01-05 00:00:00   4.6   2.8   7.2   NaN   NaN    NaN   8.2   NaN
#
#      pres  tsun
# 0  1008.2   NaN
# 1  1013.9   NaN
# 2  1010.2   NaN
# 3  1003.7   NaN
# 4  1010.1   NaN

# %%
jan_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    31 non-null     object
#  1   tavg    30 non-null     float64
#  2   tmin    30 non-null     float64
#  3   tmax    30 non-null     float64
#  4   prcp    0 non-null      float64
#  5   snow    0 non-null      float64
#  6   wdir    8 non-null      float64
#  7   wspd    30 non-null     float64
#  8   wpgt    0 non-null      float64
#  9   pres    30 non-null     float64
#  10  tsun    0 non-null      float64
# dtypes: float64(10), object(1)
# memory usage: 2.8+ KB

# %%
#convert date to datetime
jan_weather['date'] = pd.to_datetime(jan_weather['date'])
jan_weather.info()

#drop columns with no values
jan_weather.drop('prcp', axis = 1, inplace=True)
jan_weather.drop('snow', axis = 1, inplace=True)
jan_weather.drop('wpgt', axis = 1, inplace=True)
jan_weather.drop('tsun', axis = 1, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    31 non-null     datetime64[ns]
#  1   tavg    30 non-null     float64
#  2   tmin    30 non-null     float64
#  3   tmax    30 non-null     float64
#  4   prcp    0 non-null      float64
#  5   snow    0 non-null      float64
#  6   wdir    8 non-null      float64
#  7   wspd    30 non-null     float64
#  8   wpgt    0 non-null      float64
#  9   pres    30 non-null     float64
#  10  tsun    0 non-null      float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 2.8 KB

# %%
#convert C to F
def convert(x):
  tempavg = (x * 9/5) + 32
  return tempavg

# %%
jan_weather['temp_average']=jan_weather['tavg'].apply(convert)
jan_weather['temp_min']=jan_weather['tmin'].apply(convert)
jan_weather['temp_max']=jan_weather['tmax'].apply(convert)
jan_weather_2 = jan_weather.drop(12)

#dropped row of 1/13; had no info

# %%
#merge on date
df = pd.merge(trips_final, jan_weather_2, on='date', how='inner')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86951 entries, 0 to 86950
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tpep_pickup_datetime   86951 non-null  datetime64[ns]
#  1   tpep_dropoff_datetime  86951 non-null  datetime64[ns]
#  2   passenger_count        86951 non-null  float64
#  3   trip_distance          86951 non-null  float64
#  4   RatecodeID             86951 non-null  float64
#  5   PULocationID           86951 non-null  int64
#  6   DOLocationID           86951 non-null  int64
#  7   fare_amount            86951 non-null  float64
#  8   mta_tax                86951 non-null  float64
#  9   tip_amount             86951 non-null  float64
#  10  tolls_amount           86951 non-null  float64
#  11  improvement_surcharge  86951 non-null  float64
#  12  total_amount           86951 non-null  float64
#  13  Borough                86951 non-null  object
#  14  Zone                   86951 non-null  object
#  15  airport                86951 non-null  object
#  16  pickup_day             86951 non-null  object
#  17  dropoff_day            86951 non-null  object
#  18  pickup_hour            86951 non-null  int32
#  19  dropoff_hour           86951 non-null  int32
#  20  date                   86951 non-null  datetime64[ns]
#  21  day_of_week            86951 non-null  int64
#  22  pickup_timeframe       86951 non-null  int64
#  23  dropoff_timeframe      86951 non-null  int64
#  24  ride_duration          86951 non-null  float64
#  25  tavg                   86951 non-null  float64
#  26  tmin                   86951 non-null  float64
#  27  tmax                   86951 non-null  float64
#  28  wdir                   22457 non-null  float64
#  29  wspd                   86951 non-null  float64
#  30  pres                   86951 non-null  float64
#  31  temp_average           86951 non-null  float64
#  32  temp_min               86951 non-null  float64
#  33  temp_max               86951 non-null  float64
# dtypes: datetime64[ns](3), float64(19), int32(2), int64(5), object(5)
# memory usage: 21.9+ MB

# %% [markdown]
# pre-process and clean for model feeding

# %%
#fill nan with 0

df['wdir'].fillna(0, inplace=True)
# Out:
# <ipython-input-197-727fb0c18c48>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['wdir'].fillna(0, inplace=True)

# %%
for col in['airport', 'Zone']:
  df[col] = df[col].astype('category')
df.dtypes
# Out:
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# fare_amount                     float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# Borough                          object
# Zone                           category
# airport                        category
# pickup_day                       object
# dropoff_day                      object
# pickup_hour                       int32
# dropoff_hour                      int32
# date                     datetime64[ns]
# day_of_week                       int64
# pickup_timeframe                  int64
# dropoff_timeframe                 int64
# ride_duration                   float64
# tavg                            float64
# tmin                            float64
# tmax                            float64
# wdir                            float64
# wspd                            float64
# pres                            float64
# temp_average                    float64
# temp_min                        float64
# temp_max                        float64
# dtype: object

# %%
df.Zone.value_counts().sort_values(ascending=False).count()
# Out:
# np.int64(31)

# %%
from datetime import datetime
day = df['date']
df['day_of_month'] = day.dt.day

# %%
df['airport_code'] = df['airport'].astype('category').cat.codes
df['zone_code'] = df['Zone'].astype('category').cat.codes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86951 entries, 0 to 86950
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tpep_pickup_datetime   86951 non-null  datetime64[ns]
#  1   tpep_dropoff_datetime  86951 non-null  datetime64[ns]
#  2   passenger_count        86951 non-null  float64
#  3   trip_distance          86951 non-null  float64
#  4   RatecodeID             86951 non-null  float64
#  5   PULocationID           86951 non-null  int64
#  6   DOLocationID           86951 non-null  int64
#  7   fare_amount            86951 non-null  float64
#  8   mta_tax                86951 non-null  float64
#  9   tip_amount             86951 non-null  float64
#  10  tolls_amount           86951 non-null  float64
#  11  improvement_surcharge  86951 non-null  float64
#  12  total_amount           86951 non-null  float64
#  13  Borough                86951 non-null  object
#  14  Zone                   86951 non-null  category
#  15  airport                86951 non-null  category
#  16  pickup_day             86951 non-null  object
#  17  dropoff_day            86951 non-null  object
#  18  pickup_hour            86951 non-null  int32
#  19  dropoff_hour           86951 non-null  int32
#  20  date                   86951 non-null  datetime64[ns]
#  21  day_of_week            86951 non-null  int64
#  22  pickup_timeframe       86951 non-null  int64
#  23  dropoff_timeframe      86951 non-null  int64
#  24  ride_duration          86951 non-null  float64
#  25  tavg                   86951 non-null  float64
#  26  tmin                   86951 non-null  float64
#  27  tmax                   86951 non-null  float64
#  28  wdir                   86951 non-null  float64
#  29  wspd                   86951 non-null  float64
#  30  pres                   86951 non-null  float64
#  31  temp_average           86951 non-null  float64
#  32  temp_min               86951 non-null  float64
#  33  temp_max               86951 non-null  float64
#  34  day_of_month           86951 non-null  int32
#  35  airport_code           86951 non-null  int8
#  36  zone_code              86951 non-null  int8
# dtypes: category(2), datetime64[ns](3), float64(19), int32(3), int64(5), int8(2), object(3)
# memory usage: 21.2+ MB

# %%
model_df = df[['trip_distance', 'zone_code', 'ride_duration', 'pickup_hour', 'airport_code', 'day_of_month', 'temp_average']]
model_df['zone_code']
# Out:
# 0        12
# 1         7
# 2        12
# 3        13
# 4        25
#          ..
# 86946     7
# 86947     7
# 86948    13
# 86949    20
# 86950    13
# Name: zone_code, Length: 86951, dtype: int8

# %% [markdown]
# DNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.optimizers import Adam
from tensorflow.keras.layers import CategoryEncoding
import keras
import numpy as np

# %%
model_df.zone_code.unique()
#31 unique codes
# Out:
# array([12,  7, 13, 25, 14, 11,  2, 16, 15, 10, 19,  3,  5, 22, 23, 17, 18,
#        20,  4, 29,  1, 24,  8,  0, 30, 26, 28,  6, 21,  9, 27], dtype=int8)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
cat_cols = ['airport_code', 'zone_code', 'pickup_hour', 'day_of_month']
model_df = pd.get_dummies(model_df, columns= cat_cols)
model_df
# Out:
#        trip_distance  ride_duration  temp_average  airport_code_0  \
# 0               7.09          23.82         38.48           False
# 1              10.74          38.87         38.48           False
# 2               9.00          17.35         38.48           False
# 3              17.65          47.55         38.48            True
# 4              20.65          38.85         38.48            True
# ...              ...            ...           ...             ...
# 86946          16.90          33.50         39.74            True
# 86947          17.16          36.88         39.74            True
# 86948          16.87          29.98         39.74            True
# 86949          12.93          26.58         39.74           False
# 86950          16.78          24.10         39.74            True
#
#        airport_code_1  airport_code_2  zone_code_0  zone_code_1  zone_code_2  \
# 0                True           False        False        False        False
# 1                True           False        False        False        False
# 2                True           False        False        False        False
# 3               False           False        False        False        False
# 4               False           False        False        False        False
# ...               ...             ...          ...          ...          ...
# 86946           False           False        False        False        False
# 86947           False           False        False        False        False
# 86948           False           False        False        False        False
# 86949           False            True        False        False        False
# 86950           False           False        False        False        False
#
#        zone_code_3  ...  day_of_month_22  day_of_month_23  day_of_month_24  \
# 0            False  ...            False            False            False
# 1            False  ...            False            False            False
# 2            False  ...            False            False            False
# 3            False  ...            False            False            False
# 4            False  ...            False            False            False
# ...            ...  ...              ...              ...              ...
# 86946        False  ...            False            False            False
# 86947        False  ...            False            False            False
# 86948        False  ...            False            False            False
# 86949        False  ...            False            False            False
# 86950        False  ...            False            False            False
#
#        day_of_month_25  day_of_month_26  day_of_month_27  day_of_month_28  \
# 0                False            False            False            False
# 1                False            False            False            False
# 2                False            False            False            False
# 3                False            False            False            False
# 4                False            False            False            False
# ...                ...              ...              ...              ...
# 86946            False            False            False            False
# 86947            False            False            False            False
# 86948            False            False            False            False
# 86949            False            False            False            False
# 86950            False            False            False            False
#
#        day_of_month_29  day_of_month_30  day_of_month_31
# 0                False            False            False
# 1                False            False            False
# 2                False            False            False
# 3                False            False            False
# 4                False            False            False
# ...                ...              ...              ...
# 86946            False            False             True
# 86947            False            False             True
# 86948            False            False             True
# 86949            False            False             True
# 86950            False            False             True
#
# [86951 rows x 91 columns]

# %%
X = model_df.drop('ride_duration', axis = 1)

# %%
Y = model_df['ride_duration']

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.2, shuffle=True)

# %%
print(len(train_data), 'training examples')
print(len(test_data), 'test examples')
# Out:
# 69560 training examples
# 17391 test examples

# %%
#use sklearn minmaxscaler for training and validaton
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
columns_to_scale = ['trip_distance', 'temp_average']
train_data[columns_to_scale] = scaler.fit_transform(train_data[columns_to_scale])
test_data[columns_to_scale] = scaler.fit_transform(test_data[columns_to_scale])
test_data
# Out:
#        trip_distance  temp_average  airport_code_0  airport_code_1  \
# 9349        0.568747      0.581006            True           False
# 82513       0.250634      0.195531           False            True
# 86297       0.528158      0.363128            True           False
# 79754       0.278031      0.195531           False            True
# 76860       0.198376      0.318436           False            True
# ...              ...           ...             ...             ...
# 21184       0.299848      0.089385           False            True
# 78769       0.771689      0.318436            True           False
# 19534       0.173009      0.268156           False            True
# 20845       0.624556      0.089385            True           False
# 41482       0.216134      0.497207           False            True
#
#        airport_code_2  zone_code_0  zone_code_1  zone_code_2  zone_code_3  \
# 9349            False        False        False        False        False
# 82513           False        False        False        False        False
# 86297           False        False        False        False        False
# 79754           False        False        False        False        False
# 76860           False        False        False        False        False
# ...               ...          ...          ...          ...          ...
# 21184           False        False        False        False        False
# 78769           False        False        False        False        False
# 19534           False        False        False        False        False
# 20845           False        False        False        False        False
# 41482           False        False        False        False        False
#
#        zone_code_4  ...  day_of_month_22  day_of_month_23  day_of_month_24  \
# 9349         False  ...            False            False            False
# 82513        False  ...            False            False            False
# 86297        False  ...            False            False            False
# 79754        False  ...            False            False            False
# 76860        False  ...            False            False            False
# ...            ...  ...              ...              ...              ...
# 21184        False  ...            False            False            False
# 78769        False  ...            False            False            False
# 19534        False  ...            False            False            False
# 20845        False  ...            False            False            False
# 41482        False  ...            False            False            False
#
#        day_of_month_25  day_of_month_26  day_of_month_27  day_of_month_28  \
# 9349             False            False            False            False
# 82513            False            False            False            False
# 86297            False            False            False            False
# 79754            False            False            False            False
# 76860            False            False            False            False
# ...                ...              ...              ...              ...
# 21184            False            False            False            False
# 78769            False            False            False            False
# 19534            False            False            False            False
# 20845            False            False            False            False
# 41482            False            False            False            False
#
#        day_of_month_29  day_of_month_30  day_of_month_31
# 9349             False            False            False
# 82513            False             True            False
# 86297            False            False             True
# 79754            False             True            False
# 76860             True            False            False
# ...                ...              ...              ...
# 21184            False            False            False
# 78769             True            False            False
# 19534            False            False            False
# 20845            False            False            False
# 41482            False            False            False
#
# [17391 rows x 90 columns]

# %%
from keras.layers import Dropout
model = Sequential()
model.add(Dense(64, input_shape=(90,), activation= 'relu'))
model.add(Dense(32, activation ='relu'))
model.add(Dense(16, activation ='relu'))
model.add(Dense(8, activation ='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mean_absolute_error'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(x = train_data, y= train_labels, epochs=100, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 328.3036 - mean_absolute_error: 13.2855 - val_loss: 49.1551 - val_mean_absolute_error: 5.0477
# Epoch 2/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 129.8775 - mean_absolute_error: 8.6590 - val_loss: 38.0877 - val_mean_absolute_error: 4.4272
# Epoch 3/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 120.6966 - mean_absolute_error: 8.3490 - val_loss: 44.6968 - val_mean_absolute_error: 4.7472
# Epoch 4/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 111.6771 - mean_absolute_error: 7.9489 - val_loss: 40.6247 - val_mean_absolute_error: 4.5083
# Epoch 5/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 106.4994 - mean_absolute_error: 7.7572 - val_loss: 37.0865 - val_mean_absolute_error: 4.3157
# Epoch 6/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 98.4856 - mean_absolute_error: 7.4220 - val_loss: 38.1698 - val_mean_absolute_error: 4.3728
# Epoch 7/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 94.4454 - mean_absolute_error: 7.2232 - val_loss: 34.2432 - val_mean_absolute_error: 4.1757
# Epoch 8/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 87.7768 - mean_absolute_error: 6.8965 - val_loss: 37.8509 - val_mean_absolute_error: 4.3537
# Epoch 9/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 84.3559 - mean_absolute_error: 6.7363 - val_loss: 35.1854 - val_mean_absolute_error: 4.2084
# Epoch 10/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 79.1497 - mean_absolute_error: 6.5009 - val_loss: 40.5357 - val_mean_absolute_error: 4.5082
# Epoch 11/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 74.1106 - mean_absolute_error: 6.2821 - val_loss: 35.4438 - val_mean_absolute_error: 4.2156
# Epoch 12/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 69.6668 - mean_absolute_error: 6.0525 - val_loss: 30.4929 - val_mean_absolute_error: 3.9999
# Epoch 13/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 65.5199 - mean_absolute_error: 5.8414 - val_loss: 29.6456 - val_mean_absolute_error: 4.0418
# Epoch 14/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 61.8660 - mean_absolute_error: 5.6493 - val_loss: 30.7101 - val_mean_absolute_error: 4.0085
# Epoch 15/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 59.6317 - mean_absolute_error: 5.5299 - val_loss: 31.5695 - val_mean_absolute_error: 4.0588
# Epoch 16/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 56.4461 - mean_absolute_error: 5.3595 - val_loss: 32.5424 - val_mean_absolute_error: 4.0571
# Epoch 17/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 53.5311 - mean_absolute_error: 5.1727 - val_loss: 32.2250 - val_mean_absolute_error: 4.0654
# Epoch 18/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 51.6414 - mean_absolute_error: 5.0902 - val_loss: 33.6277 - val_mean_absolute_error: 4.1176
# Epoch 19/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 48.0774 - mean_absolute_error: 4.9057 - val_loss: 29.8652 - val_mean_absolute_error: 3.9990
# Epoch 20/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 46.2899 - mean_absolute_error: 4.8128 - val_loss: 29.5155 - val_mean_absolute_error: 3.9816
# Epoch 21/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 45.9776 - mean_absolute_error: 4.7823 - val_loss: 30.7466 - val_mean_absolute_error: 4.0548
# Epoch 22/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 42.3028 - mean_absolute_error: 4.6102 - val_loss: 30.0904 - val_mean_absolute_error: 3.9772
# Epoch 23/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 41.1020 - mean_absolute_error: 4.5500 - val_loss: 29.9032 - val_mean_absolute_error: 3.9866
# Epoch 24/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 40.6811 - mean_absolute_error: 4.5270 - val_loss: 31.4008 - val_mean_absolute_error: 4.0063
# Epoch 25/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 39.3454 - mean_absolute_error: 4.4576 - val_loss: 30.2232 - val_mean_absolute_error: 4.0446
# Epoch 26/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 38.3060 - mean_absolute_error: 4.4044 - val_loss: 30.2635 - val_mean_absolute_error: 4.0537
# Epoch 27/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 37.9221 - mean_absolute_error: 4.3933 - val_loss: 31.0742 - val_mean_absolute_error: 4.0458
# Epoch 28/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 35.9412 - mean_absolute_error: 4.2864 - val_loss: 29.6281 - val_mean_absolute_error: 3.9730
# Epoch 29/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 35.9050 - mean_absolute_error: 4.3154 - val_loss: 31.1216 - val_mean_absolute_error: 4.0737
# Epoch 30/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 35.4370 - mean_absolute_error: 4.2994 - val_loss: 29.4976 - val_mean_absolute_error: 3.9772
# Epoch 31/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 34.4813 - mean_absolute_error: 4.2475 - val_loss: 28.8455 - val_mean_absolute_error: 3.9953
# Epoch 32/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 34.4714 - mean_absolute_error: 4.2742 - val_loss: 28.8300 - val_mean_absolute_error: 3.9942
# Epoch 33/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 34.0109 - mean_absolute_error: 4.2204 - val_loss: 29.0799 - val_mean_absolute_error: 4.0562
# Epoch 34/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 34.6603 - mean_absolute_error: 4.2732 - val_loss: 28.8588 - val_mean_absolute_error: 4.0113
# Epoch 35/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 33.3713 - mean_absolute_error: 4.2310 - val_loss: 29.6766 - val_mean_absolute_error: 3.9831
# Epoch 36/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 33.3246 - mean_absolute_error: 4.2249 - val_loss: 28.8379 - val_mean_absolute_error: 4.0092
# Epoch 37/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 33.0415 - mean_absolute_error: 4.2240 - val_loss: 29.1455 - val_mean_absolute_error: 3.9759
# Epoch 38/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 32.4351 - mean_absolute_error: 4.1737 - val_loss: 29.2966 - val_mean_absolute_error: 3.9948
# Epoch 39/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 33.1077 - mean_absolute_error: 4.2184 - val_loss: 28.7031 - val_mean_absolute_error: 3.9651
# Epoch 40/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 32.1923 - mean_absolute_error: 4.1899 - val_loss: 29.4302 - val_mean_absolute_error: 3.9803
# Epoch 41/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 32.7722 - mean_absolute_error: 4.2123 - val_loss: 28.9300 - val_mean_absolute_error: 3.9451
# Epoch 42/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 32.4962 - mean_absolute_error: 4.1960 - val_loss: 29.2249 - val_mean_absolute_error: 4.0154
# Epoch 43/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.9404 - mean_absolute_error: 4.1750 - val_loss: 29.6990 - val_mean_absolute_error: 4.0482
# Epoch 44/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.9905 - mean_absolute_error: 4.1683 - val_loss: 29.3992 - val_mean_absolute_error: 4.0343
# Epoch 45/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 32.0290 - mean_absolute_error: 4.1728 - val_loss: 29.0580 - val_mean_absolute_error: 4.0342
# Epoch 46/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 32.0800 - mean_absolute_error: 4.1823 - val_loss: 28.9364 - val_mean_absolute_error: 4.0389
# Epoch 47/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.4560 - mean_absolute_error: 4.1404 - val_loss: 29.0939 - val_mean_absolute_error: 4.0236
# Epoch 48/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 31.7968 - mean_absolute_error: 4.1774 - val_loss: 29.6424 - val_mean_absolute_error: 4.0428
# Epoch 49/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.6373 - mean_absolute_error: 4.1800 - val_loss: 28.6639 - val_mean_absolute_error: 3.9771
# Epoch 50/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.6731 - mean_absolute_error: 4.1683 - val_loss: 28.8080 - val_mean_absolute_error: 4.0194
# Epoch 51/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.1352 - mean_absolute_error: 4.1274 - val_loss: 29.0382 - val_mean_absolute_error: 3.9897
# Epoch 52/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 31.6152 - mean_absolute_error: 4.1509 - val_loss: 28.4710 - val_mean_absolute_error: 3.9607
# Epoch 53/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.6981 - mean_absolute_error: 4.1642 - val_loss: 29.2898 - val_mean_absolute_error: 4.0137
# Epoch 54/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.6581 - mean_absolute_error: 4.1492 - val_loss: 31.3458 - val_mean_absolute_error: 4.0707
# Epoch 55/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.7088 - mean_absolute_error: 4.1684 - val_loss: 28.8000 - val_mean_absolute_error: 4.0086
# Epoch 56/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 31.6546 - mean_absolute_error: 4.1534 - val_loss: 28.7376 - val_mean_absolute_error: 4.0058
# Epoch 57/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 31.5792 - mean_absolute_error: 4.1604 - val_loss: 29.3530 - val_mean_absolute_error: 4.0263
# Epoch 58/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.6498 - mean_absolute_error: 4.1231 - val_loss: 29.0733 - val_mean_absolute_error: 4.0376
# Epoch 59/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.3922 - mean_absolute_error: 4.1612 - val_loss: 29.1305 - val_mean_absolute_error: 3.9844
# Epoch 60/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 32.0611 - mean_absolute_error: 4.1755 - val_loss: 29.2767 - val_mean_absolute_error: 3.9548
# Epoch 61/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.7685 - mean_absolute_error: 4.1793 - val_loss: 29.6235 - val_mean_absolute_error: 4.0040
# Epoch 62/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.6317 - mean_absolute_error: 4.1686 - val_loss: 28.9805 - val_mean_absolute_error: 4.0415
# Epoch 63/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.0002 - mean_absolute_error: 4.1471 - val_loss: 29.6252 - val_mean_absolute_error: 4.0052
# Epoch 64/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.8462 - mean_absolute_error: 4.1290 - val_loss: 28.7393 - val_mean_absolute_error: 3.9559
# Epoch 65/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.3460 - mean_absolute_error: 4.1046 - val_loss: 29.2743 - val_mean_absolute_error: 4.0532
# Epoch 66/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 31.0882 - mean_absolute_error: 4.1254 - val_loss: 28.7215 - val_mean_absolute_error: 3.9634
# Epoch 67/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.5630 - mean_absolute_error: 4.1256 - val_loss: 28.7765 - val_mean_absolute_error: 4.0067
# Epoch 68/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.9806 - mean_absolute_error: 4.1283 - val_loss: 29.0332 - val_mean_absolute_error: 4.0252
# Epoch 69/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 31.3310 - mean_absolute_error: 4.1552 - val_loss: 28.5354 - val_mean_absolute_error: 3.9844
# Epoch 70/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 30.2046 - mean_absolute_error: 4.0718 - val_loss: 29.1406 - val_mean_absolute_error: 3.9619
# Epoch 71/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.4382 - mean_absolute_error: 4.0898 - val_loss: 28.9855 - val_mean_absolute_error: 3.9626
# Epoch 72/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.5963 - mean_absolute_error: 4.0478 - val_loss: 28.8539 - val_mean_absolute_error: 3.9582
# Epoch 73/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.3111 - mean_absolute_error: 4.0759 - val_loss: 28.8339 - val_mean_absolute_error: 4.0034
# Epoch 74/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.3878 - mean_absolute_error: 4.0300 - val_loss: 29.7187 - val_mean_absolute_error: 3.9996
# Epoch 75/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 29.7468 - mean_absolute_error: 4.0439 - val_loss: 29.3381 - val_mean_absolute_error: 3.9934
# Epoch 76/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.5502 - mean_absolute_error: 4.0955 - val_loss: 29.2885 - val_mean_absolute_error: 4.0186
# Epoch 77/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.9165 - mean_absolute_error: 4.0647 - val_loss: 28.4432 - val_mean_absolute_error: 3.9196
# Epoch 78/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.8445 - mean_absolute_error: 4.0515 - val_loss: 29.8966 - val_mean_absolute_error: 4.0352
# Epoch 79/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.5263 - mean_absolute_error: 4.0517 - val_loss: 29.2524 - val_mean_absolute_error: 4.0370
# Epoch 80/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 29.4666 - mean_absolute_error: 4.0380 - val_loss: 29.2139 - val_mean_absolute_error: 3.9771
# Epoch 81/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 30.1744 - mean_absolute_error: 4.0762 - val_loss: 29.6672 - val_mean_absolute_error: 4.0128
# Epoch 82/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.1156 - mean_absolute_error: 4.0147 - val_loss: 29.3683 - val_mean_absolute_error: 3.9955
# Epoch 83/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.3136 - mean_absolute_error: 4.0296 - val_loss: 29.3674 - val_mean_absolute_error: 3.9841
# Epoch 84/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.2835 - mean_absolute_error: 4.0307 - val_loss: 29.1094 - val_mean_absolute_error: 3.9881
# Epoch 85/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.8261 - mean_absolute_error: 4.0558 - val_loss: 29.3367 - val_mean_absolute_error: 4.0198
# Epoch 86/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.4395 - mean_absolute_error: 4.0564 - val_loss: 29.2174 - val_mean_absolute_error: 4.0029
# Epoch 87/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.7415 - mean_absolute_error: 4.0616 - val_loss: 29.6428 - val_mean_absolute_error: 4.0568
# Epoch 88/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.2571 - mean_absolute_error: 4.0370 - val_loss: 29.4462 - val_mean_absolute_error: 4.0812
# Epoch 89/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 28.6234 - mean_absolute_error: 3.9849 - val_loss: 29.4436 - val_mean_absolute_error: 4.0638
# Epoch 90/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 28.9923 - mean_absolute_error: 4.0028 - val_loss: 28.8333 - val_mean_absolute_error: 3.9942
# Epoch 91/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.4054 - mean_absolute_error: 4.0435 - val_loss: 29.6503 - val_mean_absolute_error: 4.0496
# Epoch 92/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 28.5640 - mean_absolute_error: 3.9951 - val_loss: 29.2064 - val_mean_absolute_error: 3.9958
# Epoch 93/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.9254 - mean_absolute_error: 4.0582 - val_loss: 29.0058 - val_mean_absolute_error: 3.9728
# Epoch 94/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 29.1525 - mean_absolute_error: 4.0200 - val_loss: 29.0308 - val_mean_absolute_error: 4.0326
# Epoch 95/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.4950 - mean_absolute_error: 4.0521 - val_loss: 28.8922 - val_mean_absolute_error: 3.9657
# Epoch 96/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.3265 - mean_absolute_error: 4.0443 - val_loss: 29.8772 - val_mean_absolute_error: 4.0620
# Epoch 97/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.6574 - mean_absolute_error: 4.0477 - val_loss: 29.0759 - val_mean_absolute_error: 4.0027
# Epoch 98/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 29.4494 - mean_absolute_error: 4.0451 - val_loss: 29.2582 - val_mean_absolute_error: 4.0093
# Epoch 99/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 29.0965 - mean_absolute_error: 4.0271 - val_loss: 29.7086 - val_mean_absolute_error: 4.0184
# Epoch 100/100
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 28.4258 - mean_absolute_error: 3.9909 - val_loss: 29.2237 - val_mean_absolute_error: 4.0289

# %%
results = model.evaluate(test_data, test_labels, verbose = 1)
print('Test loss:', results)
# Out:
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.9540 - mean_absolute_error: 4.0446
# Test loss: [28.909276962280273, 4.034097671508789]

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# %%
import matplotlib as plt

# %%
epochs = range(1, len(training_loss) + 1)
plt.pyplot.plot(epochs, training_loss, 'g', label='Training loss')
plt.pyplot.plot(epochs, validation_loss, 'b', label='Validation loss')
plt.pyplot.title('Training and Validation Loss')
plt.pyplot.xlabel('Epochs')
plt.pyplot.ylabel('Loss')
plt.pyplot.legend()
plt.pyplot.show()

# %%
import matplotlib.pyplot as plt

predictions = model.predict(test_data)
a = plt.axes(aspect='equal')
plt.scatter(test_labels, predictions, alpha=0.5)
plt.xlabel('True Values [ride_duration]')
plt.ylabel('Predictions [ride_duration]')
lims = [0, 80]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
